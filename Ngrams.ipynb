# %% [markdown]
# # Exploring Financial News using N-grams and Stop Words

# %%
#import libraries
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
import spacy
import string

# %% [markdown]
# ## Import Data

# %%
#load news data
data = pd.read_excel('C:/Users/beyku/CPT346 Assignment 1/data.csv', quotechar="'")

# %%
data.head(5)
# Out:
#         Date                                               News  \
# 0 2007-12-15  Credit market strains hang on banks results\n\...
# 1 2007-12-15  Dollar likely to weather any U.S. recession\n\...
# 2 2007-12-14  Central bank plan delays day of reckoning\n\nN...
# 3 2007-12-14  Inflation seen hanging over 2008 world economy...
# 4 2007-12-14  Investors see housing as top U.S. election the...
#
#                                               Source
# 0  https://www.reuters.com/article/us-investment-...
# 1  https://www.reuters.com/article/us-investment-...
# 2  https://www.reuters.com/article/us-investment-...
# 3  https://www.reuters.com/article/us-investment-...
# 4  https://www.reuters.com/article/us-investment-...

# %%
#extract only news content
news = data['News']
news.head(5)
# Out:
# 0    Credit market strains hang on banks results\n\...
# 1    Dollar likely to weather any U.S. recession\n\...
# 2    Central bank plan delays day of reckoning\n\nN...
# 3    Inflation seen hanging over 2008 world economy...
# 4    Investors see housing as top U.S. election the...
# Name: News, dtype: object

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Remove Non-ASCII Characters

# %%
#function to remove non-ascii character
def remove_non_ascii(string):
    non_ascii_removed = ""
    for char in string:
        if ord(char) < 128:
            non_ascii_removed = non_ascii_removed + char
    return non_ascii_removed

# %%
news = news.astype(str)

# %%
#remove non-ascii character
for i, new in enumerate(news):
    news[i] = remove_non_ascii(new)

# %%
news.head()
# Out:
# 0    Credit market strains hang on banks results\n\...
# 1    Dollar likely to weather any U.S. recession\n\...
# 2    Central bank plan delays day of reckoning\n\nN...
# 3    Inflation seen hanging over 2008 world economy...
# 4    Investors see housing as top U.S. election the...
# Name: News, dtype: object

# %% [markdown]
# ### Replace Punctuations, New Line, Carriage Return and Tab with White Space

# %%
#remove punctuations, newline etc with white space
regex = re.compile('[' + re.escape(string.punctuation) + '\\r\\t\\n]')
for i, new in enumerate(news):
    news[i] = regex.sub(" ", str(new))

# %%
news.head(5)
# Out:
# 0    Credit market strains hang on banks results  N...
# 1    Dollar likely to weather any U S  recession  N...
# 2    Central bank plan delays day of reckoning  NEW...
# 3    Inflation seen hanging over 2008 world economy...
# 4    Investors see housing as top U S  election the...
# Name: News, dtype: object

# %% [markdown]
# ### Tokenization & Lemmatization

# %%
#load spacy egnlish model
nlp = spacy.load('en_core_web_sm')

# %%
#use loaded english model to tokenize the news into words
#then use the tokenized words to get their baseforms or lemma to replace them
for i, new in enumerate(news):    
    doc = nlp(new, disable=['parser','ner'])
    news[i] = [token.lemma_ for token in doc]

# %%
news.head(5)
# Out:
# 0    [credit, market, strain, hang, on, bank, resul...
# 1    [dollar, likely, to, weather, any, U, S,  , re...
# 2    [central, bank, plan, delay, day, of, reckon, ...
# 3    [inflation, see, hang, over, 2008, world, econ...
# 4    [investor, see, housing, as, top, U, S,  , ele...
# Name: News, dtype: object

# %% [markdown]
# ### Lowercase All Words

# %%
#lowercase all words
for i, new in enumerate(news):
    lowercase_new = []
    for word in new:
        lowercase_new.append(word.lower())
    news[i] = lowercase_new

# %%
news.head()
# Out:
# 0    [credit, market, strain, hang, on, bank, resul...
# 1    [dollar, likely, to, weather, any, u, s,  , re...
# 2    [central, bank, plan, delay, day, of, reckon, ...
# 3    [inflation, see, hang, over, 2008, world, econ...
# 4    [investor, see, housing, as, top, u, s,  , ele...
# Name: News, dtype: object

# %%
#build a list to store all the tokens
token_list = []
for new in news:
    for word in new:
        token_list.append(word)

# %%
token_list
# Out:
# ['credit',
#  'market',
#  'strain',
#  'hang',
#  'on',
#  'bank',
#  'result',
#  ' ',
#  'new',
#  'york',
#  ' ',
#  'reuters',
#  '   ',
#  'credit',
#  'market',
#  'strain',
#  'may',
#  'start',
#  'to',
#  'abate',
#  'in',
#  'early',
#  '2008',
#  'once',
#  'bank',
#  'get',
#  'through',
#  'the',
#  'next',
#  'round',
#  'of',
#  'reveal',
#  'loss',
#  'from',
#  'risky',
#  'asset',
#  ' ',
#  'fund',
#  'manager',
#  'at',
#  'the',
#  'reuters',
#  'investment',
#  'outlook',
#  '2008',
#  'summit',
#  'say',
#  'this',
#  'week',
#  '  ',
#  'central',
#  'bank',
#  'plan',
#  ' ',
#  'unveil',
#  'on',
#  'wednesday',
#  ' ',
#  'to',
#  'add',
#  'temporary',
#  'reserve',
#  'may',
#  'also',
#  'help',
#  'to',
#  'cushion',
#  'the',
#  'global',
#  'banking',
#  'system',
#  'from',
#  'shock',
#  'of',
#  'more',
#  'loss',
#  'from',
#  'the',
#  'melt',
#  'down',
#  'in',
#  'u',
#  's',
#  ' ',
#  'subprime',
#  'mortgage',
#  ' ',
#  'but',
#  'for',
#  'elevated',
#  'short',
#  'term',
#  'borrowing',
#  'cost',
#  'to',
#  'come',
#  'down',
#  'substantially',
#  ' ',
#  'market',
#  'participant',
#  'need',
#  'a',
#  'more',
#  'up',
#  'to',
#  'date',
#  'tally',
#  'of',
#  'how',
#  'much',
#  'red',
#  'ink',
#  'the',
#  'banking',
#  'system',
#  'have',
#  'bleed',
#  ' ',
#  'fund',
#  'manager',
#  'say',
#  '  ',
#  'until',
#  'then',
#  ' ',
#  'the',
#  'specter',
#  'of',
#  'uncertainty',
#  'about',
#  'bank',
#  'unknown',
#  'loss',
#  'in',
#  'credit',
#  'market',
#  'will',
#  'likely',
#  'haunt',
#  'bank',
#  'and',
#  'clam',
#  'up',
#  'lend',
#  ' ',
#  'bank',
#  'financial',
#  'result',
#  'issue',
#  'in',
#  'early',
#  '2008',
#  'may',
#  'be',
#  'ugly',
#  ' ',
#  'but',
#  'investor',
#  'will',
#  'be',
#  'relieve',
#  'to',
#  'know',
#  'the',
#  'bad',
#  '  ',
#  'tom',
#  'sowanick',
#  ' ',
#  'chief',
#  'investment',
#  'officer',
#  'with',
#  'clearbrook',
#  'financial',
#  'llc',
#  'in',
#  'princeton',
#  ' ',
#  'new',
#  'jersey',
#  ' ',
#  'say',
#  'concern',
#  'about',
#  'the',
#  'structured',
#  'credit',
#  'that',
#  'bank',
#  'and',
#  'brokerage',
#  'firm',
#  'own',
#  ' ',
#  'will',
#  'come',
#  'to',
#  'a',
#  'rest',
#  'by',
#  'the',
#  'end',
#  'of',
#  'the',
#  'first',
#  'quarter',
#  'or',
#  'the',
#  'end',
#  'of',
#  'the',
#  'second',
#  'quarter',
#  'at',
#  'the',
#  'late',
#  'because',
#  ' ',
#  'by',
#  'then',
#  ' ',
#  'many',
#  'financial',
#  'firm',
#  'report',
#  'and',
#  'they',
#  'wo',
#  'nt',
#  'hide',
#  'that',
#  'from',
#  'their',
#  'auditor',
#  '  ',
#  'for',
#  'now',
#  ' ',
#  'bank',
#  'be',
#  'hoard',
#  'cash',
#  'to',
#  'cushion',
#  'themselves',
#  'against',
#  'the',
#  'risk',
#  'of',
#  'more',
#  'write',
#  'down',
#  'and',
#  'against',
#  'so',
#  'call',
#  'counterparty',
#  'risk',
#  'in',
#  'interbank',
#  'lending',
#  'market',
#  ' ',
#  'the',
#  'danger',
#  'that',
#  'a',
#  'borrower',
#  'might',
#  'not',
#  'be',
#  'able',
#  'to',
#  'repay',
#  'a',
#  'short',
#  'term',
#  'loan',
#  ' ',
#  'these',
#  'trend',
#  'have',
#  'keep',
#  'short',
#  'term',
#  'lending',
#  'rate',
#  'atypically',
#  'high',
#  'since',
#  'credit',
#  'market',
#  'turmoil',
#  'erupt',
#  'in',
#  'august',
#  '  ',
#  'libor',
#  ' ',
#  'or',
#  'the',
#  'london',
#  'interbank',
#  'offer',
#  'rate',
#  ' ',
#  'be',
#  'some',
#  '75',
#  'basis',
#  'point',
#  'above',
#  'the',
#  'federal',
#  'fund',
#  'target',
#  'rate',
#  ' ',
#  'the',
#  'key',
#  'u',
#  's',
#  ' ',
#  'overnight',
#  'lending',
#  'rate',
#  ' ',
#  'that',
#  's',
#  'way',
#  'above',
#  'its',
#  'historical',
#  'long',
#  'term',
#  'average',
#  'of',
#  'within',
#  'about',
#  '12',
#  '5',
#  'basis',
#  'point',
#  ' ',
#  'analyst',
#  'note',
#  '  ',
#  'libor',
#  ' ',
#  'the',
#  'main',
#  'short',
#  'term',
#  'borrowing',
#  'rate',
#  'in',
#  'europe',
#  'and',
#  'for',
#  'adjustable',
#  'rate',
#  'mortgage',
#  'in',
#  'the',
#  'united',
#  'states',
#  ' ',
#  'be',
#  'likely',
#  'to',
#  'remain',
#  'high',
#  'into',
#  'the',
#  'first',
#  'quarter',
#  ' ',
#  'say',
#  'deborah',
#  'cunningham',
#  ' ',
#  'who',
#  'manage',
#  'federated',
#  'investor',
#  'u',
#  's',
#  ' ',
#  'and',
#  'euro',
#  'money',
#  'market',
#  'fund',
#  'total',
#  ' ',
#  '210',
#  'billion',
#  'in',
#  'asset',
#  '  ',
#  'in',
#  'europe',
#  ' ',
#  'bank',
#  'be',
#  'not',
#  'trustworthy',
#  'of',
#  'each',
#  'other',
#  'in',
#  'short',
#  'term',
#  'lending',
#  'market',
#  ' ',
#  'say',
#  'cunningham',
#  ' ',
#  'who',
#  'chief',
#  'investment',
#  'officer',
#  'for',
#  'taxable',
#  'money',
#  'market',
#  'at',
#  'federated',
#  'investors',
#  'inc',
#  '  ',
#  'until',
#  'there',
#  'be',
#  'a',
#  'lot',
#  'of',
#  'year',
#  'end',
#  'of',
#  'report',
#  ' ',
#  'that',
#  'rate',
#  ' ',
#  'the',
#  'spread',
#  'of',
#  'libor',
#  'over',
#  'the',
#  'u',
#  's',
#  ' ',
#  'feed',
#  'fund',
#  'target',
#  'rate',
#  ' ',
#  'will',
#  'stay',
#  'wide',
#  ' ',
#  'cunningham',
#  'say',
#  '  ',
#  'most',
#  'european',
#  'bank',
#  'be',
#  'expect',
#  'to',
#  'report',
#  'their',
#  'next',
#  'round',
#  'of',
#  'financial',
#  'result',
#  'between',
#  'mid',
#  'february',
#  'and',
#  'early',
#  'march',
#  '  ',
#  'by',
#  'mid',
#  '2008',
#  ' ',
#  'when',
#  'most',
#  'bank',
#  'write',
#  'off',
#  'from',
#  'subprime',
#  'mortgage',
#  'debt',
#  'relate',
#  'loss',
#  'will',
#  'have',
#  'be',
#  'undertake',
#  ' ',
#  'the',
#  'libor',
#  'feed',
#  'fund',
#  'target',
#  'rate',
#  'spread',
#  'should',
#  'shrink',
#  ' ',
#  'say',
#  'margaret',
#  'patel',
#  ' ',
#  'manage',
#  'director',
#  'and',
#  'senior',
#  'portfolio',
#  'manager',
#  'with',
#  'evergreen',
#  'investment',
#  'management',
#  'company',
#  ' ',
#  'llc',
#  'in',
#  'boston',
#  '  ',
#  'she',
#  'add',
#  'that',
#  'bank',
#  'have',
#  'adequate',
#  'capital',
#  'ratio',
#  'to',
#  'absorb',
#  'such',
#  'loss',
#  '  ',
#  'yet',
#  'many',
#  'uncertainty',
#  'remain',
#  'after',
#  'a',
#  'frighteningly',
#  'swift',
#  'erosion',
#  'of',
#  'investor',
#  'confidence',
#  '  ',
#  'the',
#  'upheaval',
#  'in',
#  'short',
#  'term',
#  'money',
#  'market',
#  'include',
#  'the',
#  'u',
#  's',
#  ' ',
#  'asset',
#  'back',
#  'commercial',
#  'paper',
#  'market',
#  ' ',
#  'which',
#  'have',
#  'shrink',
#  'by',
#  'one',
#  'third',
#  'since',
#  'august',
#  ' ',
#  'be',
#  'one',
#  'of',
#  'the',
#  'big',
#  'upset',
#  'to',
#  'investor',
#  'in',
#  '2007',
#  ' ',
#  'some',
#  'see',
#  'potential',
#  'for',
#  'the',
#  'tumult',
#  'to',
#  'last',
#  'much',
#  'far',
#  'into',
#  '2008',
#  'and',
#  'perhaps',
#  'beyond',
#  '  ',
#  'and',
#  'some',
#  'fund',
#  'manager',
#  'warn',
#  'that',
#  'the',
#  'banking',
#  'system',
#  'may',
#  'face',
#  'a',
#  'much',
#  'big',
#  'problem',
#  'than',
#  'most',
#  'analyst',
#  'realize',
#  ' ',
#  'that',
#  's',
#  'because',
#  'the',
#  'slicing',
#  'and',
#  'dicing',
#  'of',
#  'u',
#  's',
#  ' ',
#  'mortgage',
#  'back',
#  'asset',
#  'that',
#  'turn',
#  'bad',
#  'have',
#  'spread',
#  'so',
#  'widely',
#  'throughout',
#  'the',
#  'world',
#  'as',
#  'bank',
#  'take',
#  'stake',
#  'in',
#  'collateralized',
#  'debt',
#  'obligation',
#  'and',
#  'structured',
#  'investment',
#  'vehicle',
#  ' ',
#  'the',
#  'extent',
#  'of',
#  'exposure',
#  'via',
#  'these',
#  'vehicle',
#  'be',
#  'very',
#  'hard',
#  'to',
#  'pin',
#  'down',
#  '  ',
#  'there',
#  'be',
#  'a',
#  'grow',
#  'opinion',
#  'that',
#  'not',
#  'necessarily',
#  'interest',
#  'rate',
#  'be',
#  'too',
#  'high',
#  'but',
#  'the',
#  'problem',
#  'in',
#  'credit',
#  'market',
#  'need',
#  'a',
#  'clean',
#  'resolution',
#  ' ',
#  'say',
#  'robert',
#  'kowit',
#  ' ',
#  'an',
#  'international',
#  'bond',
#  'fund',
#  'manager',
#  'with',
#  'federated',
#  'investors',
#  '  ',
#  'kowit',
#  'caution',
#  'that',
#  'although',
#  'investor',
#  'be',
#  'mostly',
#  'scrutinize',
#  'the',
#  'result',
#  'of',
#  'european',
#  'bank',
#  ' ',
#  'who',
#  'be',
#  'quick',
#  'to',
#  'reveal',
#  'they',
#  'have',
#  'be',
#  'hurt',
#  'by',
#  'the',
#  'crash',
#  'in',
#  'subprime',
#  'u',
#  's',
#  ' ',
#  'mortgage',
#  'asset',
#  'catch',
#  'in',
#  'the',
#  'housing',
#  'market',
#  'slump',
#  'here',
#  ' ',
#  'these',
#  'loss',
#  'may',
#  'batter',
#  'asian',
#  'investor',
#  'more',
#  'than',
#  'have',
#  'become',
#  'apparent',
#  ' ',
#  'dollar',
#  'likely',
#  'to',
#  'weather',
#  'any',
#  'u',
#  's',
#  ' ',
#  'recession',
#  ' ',
#  'new',
#  'york',
#  ' ',
#  'reuters',
#  '   ',
#  'a',
#  'u',
#  's',
#  ' ',
#  'recession',
#  'could',
#  'ironically',
#  'boost',
#  'the',
#  'dollar',
#  'against',
#  'the',
#  'euro',
#  'and',
#  'high',
#  'yield',
#  'currency',
#  'as',
#  'worried',
#  'investor',
#  'avoid',
#  'risk',
#  ' ',
#  'but',
#  'much',
#  'would',
#  'depend',
#  'on',
#  'the',
#  'depth',
#  'of',
#  'the',
#  'downturn',
#  'and',
#  'its',
#  'impact',
#  'elsewhere',
#  '  ',
#  'this',
#  'be',
#  'the',
#  'view',
#  'of',
#  'participant',
#  'at',
#  'this',
#  'week',
#  'reuters',
#  'investment',
#  'outlook',
#  '2008',
#  'summit',
#  'in',
#  'new',
#  'york',
#  ' ',
#  'who',
#  'also',
#  'note',
#  'that',
#  'dollar',
#  'weakness',
#  'next',
#  'year',
#  'would',
#  'be',
#  'mostly',
#  'versus',
#  'asian',
#  'and',
#  'some',
#  'emerge',
#  'market',
#  'currency',
#  ' ',
#  'these',
#  'economy',
#  ' ',
#  'they',
#  'say',
#  ' ',
#  'would',
#  'be',
#  'force',
#  'to',
#  'allow',
#  'their',
#  'currency',
#  'to',
#  'strengthen',
#  'to',
#  'beat',
#  'inflation',
#  'cause',
#  'by',
#  'high',
#  'import',
#  'price',
#  '  ',
#  'a',
#  'u',
#  's',
#  ' ',
#  'recession',
#  'couple',
#  'with',
#  'evidence',
#  'of',
#  'global',
#  'stress',
#  'could',
#  'lead',
#  'to',
#  'flight',
#  'to',
#  'quality',
#  'flow',
#  'into',
#  'the',
#  'dollar',
#  '  ',
#  'if',
#  'the',
#  'u',
#  's',
#  ' ',
#  'go',
#  'into',
#  'recession',
#  'and',
#  'it',
#  'look',
#  'like',
#  'its',
#  'go',
#  'to',
#  'have',
#  'a',
#  'knock',
#  'on',
#  'in',
#  'other',
#  'major',
#  'economy',
#  ' ',
#  'the',
#  'dollar',
#  'may',
#  'actually',
#  'outperform',
#  'in',
#  'a',
#  'recessionary',
#  'environment',
#  ' ',
#  'say',
#  'robert',
#  'kowit',
#  ' ',
#  'an',
#  'international',
#  'bond',
#  'fund',
#  'manager',
#  'with',
#  'federated',
#  'investors',
#  '  ',
#  'analyst',
#  'reckon',
#  'that',
#  ' ',
#  'despite',
#  'increase',
#  'talk',
#  'of',
#  'economic',
#  'de',
#  'coupling',
#  ' ',
#  'the',
#  'export',
#  'reliant',
#  'euro',
#  'zone',
#  'economy',
#  'would',
#  'be',
#  'unable',
#  'to',
#  'withstand',
#  'a',
#  'recession',
#  'in',
#  'the',
#  'united',
#  'states',
#  'and',
#  'that',
#  'would',
#  'put',
#  'the',
#  'brake',
#  'on',
#  'the',
#  ...]

# %% [markdown]
# ## Build N-grams

# %% [markdown]
# ### Build Bigrams

# %%
bigrams = nltk.collocations.BigramAssocMeasures()
bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(token_list)

# %% [markdown]
# ### Build Trigrams

# %%
trigrams = nltk.collocations.TrigramAssocMeasures()
trigramFinder = nltk.collocations.TrigramCollocationFinder.from_words(token_list)

# %% [markdown]
# ## Text Analysis

# %% [markdown]
# ### Bigrams Frequency/Count Table

# %%
bigram_count = bigramFinder.ngram_fd.items()
bigramCountTable = pd.DataFrame(list(bigram_count), columns=['Bigram','Count']).sort_values(by='Count', ascending=False)

# %%
#Top 10 count of bigrams
bigramCountTable[:10]
# Out:
#           Bigram  Count
# 192    (of, the)    125
# 327    (in, the)    122
# 119     ( , the)    109
# 484    (  , the)     89
# 346     ( , and)     79
# 1279  (the, fed)     59
# 79        (s,  )     50
# 171     ( , say)     48
# 78        (u, s)     46
# 432   (have, be)     46

# %% [markdown]
# ### Filter Bigrams Frequency/Count Table using Stop Words and Part-of-Speech tags

# %%
#get english stop words
stopwords = set(stopwords.words('english'))

# %%
#function to filter for bigrams using stop words and pos tags
def bigram_filter(bigram):
    if '-pron-' in bigram or '' in bigram or ' 'in bigram or 't' in bigram:
        return False
    for word in bigram:
        if word in stopwords:
            return False
    first_word_tag = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    second_word_tag = ('NN', 'NNS', 'NNP', 'NNPS')
    tags = nltk.pos_tag(bigram)
    if tags[0][1] in first_word_tag and tags[1][1] in second_word_tag:
        return True
    else:
        return False

# %%
#filter bigrams
filtered_bigram_count = bigramCountTable[bigramCountTable.Bigram.map(lambda x: bigram_filter(x))]

# %%
#top 10 filtered bigrams
filtered_bigram_count[:10]
# Out:
#                     Bigram  Count
# 599       (interest, rate)     29
# 8              (new, york)     28
# 649      (housing, market)     25
# 9355          (sub, prime)     23
# 1671        (wall, street)     23
# 81    (subprime, mortgage)     22
# 48         (central, bank)     22
# 0         (credit, market)     19
# 1238    (federal, reserve)     17
# 1954           (rate, cut)     16

# %% [markdown]
# ### Bigrams Pointwise Mutual Information Table

# %%
bigramFinder.apply_freq_filter(10)

# %%
bigramPMITable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.pmi)), columns=['Bigram','PMI']).sort_values(by='PMI', ascending=False)
bigramPMITable[:10]
# Out:
#                 Bigram       PMI
# 0       (fortune, 500)  9.970096
# 1       (wall, street)  9.854619
# 2          (per, cent)  9.809975
# 3         (sub, prime)  9.798036
# 4        (short, term)  9.720868
# 5   (federal, reserve)  9.480030
# 6  (percentage, point)  9.165767
# 7          (new, york)  8.498475
# 8     (back, security)  8.099926
# 9         (last, week)  8.096820

# %% [markdown]
# ### Filter Bigrams PMI Table using Stop Words and Part of Speech Tags

# %%
filtered_bigram_PMI = bigramPMITable[bigramPMITable.Bigram.map(lambda x: bigram_filter(x))]

# %%
#top 10 filtered bigrams pmi
filtered_bigram_PMI[:10]
# Out:
#                  Bigram       PMI
# 1        (wall, street)  9.854619
# 3          (sub, prime)  9.798036
# 4         (short, term)  9.720868
# 5    (federal, reserve)  9.480030
# 6   (percentage, point)  9.165767
# 7           (new, york)  8.498475
# 9          (last, week)  8.096820
# 13      (central, bank)  7.325366
# 14     (interest, rate)  7.245973
# 20    (housing, market)  5.965379

# %% [markdown]
# ## Trigrams Frequency/Count Table

# %%
trigram_count = trigramFinder.ngram_fd.items()
trigramCountTable = pd.DataFrame(list(trigram_count), columns=['Trigram','Count']).sort_values(by='Count', ascending=False)

# %%
trigramCountTable[:10]
# Out:
#                        Trigram  Count
# 80                   (u, s,  )     46
# 437                (the, u, s)     18
# 1194              ( , he, say)     15
# 16801           ( , charts,  )     15
# 1195             (he, say,   )     14
# 1439   (the, federal, reserve)     14
# 16864        ( , fortune, 500)     13
# 16863     (charts,  , fortune)     13
# 4779        (mr,  , greenspan)     12
# 730     (the, housing, market)     12

# %% [markdown]
# ### Filter Trigrams Frequency/Count Table using Stop Words and Part-of-Speech tags

# %%
#function to filter trigrams using stop words and pos tags
def trigram_filter(trigram):
    if '-pron-' in trigram or '' in trigram or ' 'in trigram or '  ' in trigram or 't' in trigram:
        return False
    for word in trigram:
        if word in stopwords:
            return False
    first_word_tag = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    third_word_tag = ('JJ', 'JJR', 'JJS', 'NN', 'NNS', 'NNP', 'NNPS')
    tags = nltk.pos_tag(trigram)
    if tags[0][1] in first_word_tag and tags[2][1] in third_word_tag:
        return True
    else:
        return False

# %%
filtered_trigram_count = trigramCountTable[trigramCountTable.Trigram.map(lambda x: trigram_filter(x))]

# %%
filtered_trigram_count[:10]
# Out:
#                                   Trigram  Count
# 5850           (mortgage, back, security)     10
# 13047              (sub, prime, mortgage)      8
# 640    (collateralized, debt, obligation)      6
# 167          (chief, investment, officer)      6
# 353          (adjustable, rate, mortgage)      6
# 14354               (sub, prime, lending)      5
# 3041         (subprime, mortgage, crisis)      5
# 7493                (cnnmoney, com,     )      5
# 382                 (money, market, fund)      5
# 1503         (quarter, percentage, point)      4

# %% [markdown]
# ### Trigrams Pointwise Mutual Information Table

# %%
trigramFinder.apply_freq_filter(5)

# %%
trigramPMITable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.pmi)), columns=['Trigram','PMI']).sort_values(by='PMI', ascending=False)
trigramPMITable[:10]
# Out:
#                               Trigram        PMI
# 0               (cnnmoney, com,     )  23.353094
# 1  (collateralized, debt, obligation)  21.382241
# 2        (chief, investment, officer)  18.888426
# 3         (nationally, charter, bank)  18.745231
# 4               (sub, prime, lending)  17.050483
# 5                         (s, p, 500)  16.019671
# 6                  ( , cnnmoney, com)  15.990274
# 7              (sub, prime, mortgage)  15.854086
# 8               (the, united, states)  15.570817
# 9          (mortgage, back, security)  15.542034

# %% [markdown]
# ### Filter Trigrams PMI Table using Stop Words and Part of Speech Tags

# %%
filtered_trigram_PMI = trigramPMITable[trigramPMITable.Trigram.map(lambda x: trigram_filter(x))]

# %%
#top 10 filtered trigrams pmi
filtered_trigram_PMI[:10]
# Out:
#                                Trigram        PMI
# 0                (cnnmoney, com,     )  23.353094
# 1   (collateralized, debt, obligation)  21.382241
# 2         (chief, investment, officer)  18.888426
# 4                (sub, prime, lending)  17.050483
# 7               (sub, prime, mortgage)  15.854086
# 9           (mortgage, back, security)  15.542034
# 10        (adjustable, rate, mortgage)  14.596961
# 16               (money, market, fund)  13.359318
# 21        (subprime, mortgage, crisis)  12.363842

# %% [markdown]
# ## Comparison of Bigrams and Trigrams

# %%
bi_count_pair = filtered_bigram_count[:20].Bigram.values
bi_pmi_pair = filtered_bigram_PMI[:20].Bigram.values
tri_count_pair = filtered_trigram_count[:20].Trigram.values
tri_pmi_pair = filtered_trigram_PMI[:20].Trigram.values
bi_count = filtered_bigram_count[:20].Count.values
bi_pmi = filtered_bigram_PMI[:20].PMI.values
tri_count = filtered_trigram_count[:20].Count.values
tri_pmi = filtered_trigram_PMI[:20].PMI.values
table = pd.DataFrame([bi_count_pair, bi_count, bi_pmi_pair, bi_pmi, tri_count_pair, tri_count, tri_pmi_pair, tri_pmi]).T
table.columns = ['Bigrams', 'Count', 'Bigrams', 'PMI', 'Trigrams', 'Count', 'Trigrams', 'PMI']

# %%
table
# Out:
#                  Bigrams Count               Bigrams      PMI  \
# 0       (interest, rate)    29        (wall, street)  9.85462
# 1            (new, york)    28          (sub, prime)  9.79804
# 2      (housing, market)    25         (short, term)  9.72087
# 3           (sub, prime)    23    (federal, reserve)  9.48003
# 4         (wall, street)    23   (percentage, point)  9.16577
# 5   (subprime, mortgage)    22           (new, york)  8.49848
# 6        (central, bank)    22          (last, week)  8.09682
# 7       (credit, market)    19       (central, bank)  7.32537
# 8     (federal, reserve)    17      (interest, rate)  7.24597
# 9            (rate, cut)    16     (housing, market)  5.96538
# 10         (percent,   )    15      (subprime, loan)  5.80848
# 11         (short, term)    14           (rate, cut)  5.65103
# 12      (subprime, loan)    12  (subprime, mortgage)  5.64673
# 13          (market,   )    12         (home, price)  5.59569
# 14            (year,   )    11    (mortgage, crisis)  5.39519
# 15         (home, price)    11      (credit, market)  5.35691
# 16          (last, week)    11           (cut, rate)  4.97295
# 17    (mortgage, crisis)    11         (percent,   )  2.55313
# 18   (percentage, point)    10            (year,   )  1.99988
# 19           (cut, rate)    10          (market,   )  1.55509
#
#                               Trigrams Count  \
# 0           (mortgage, back, security)    10
# 1               (sub, prime, mortgage)     8
# 2   (collateralized, debt, obligation)     6
# 3         (chief, investment, officer)     6
# 4         (adjustable, rate, mortgage)     6
# 5                (sub, prime, lending)     5
# 6         (subprime, mortgage, crisis)     5
# 7                (cnnmoney, com,     )     5
# 8                (money, market, fund)     5
# 9         (quarter, percentage, point)     4
# 10      (reuters, investment, outlook)     4
# 11              (term, interest, rate)     4
# 12              (president, george, w)     4
# 13              (enhanced, cash, fund)     3
# 14         (international, bond, fund)     3
# 15               (bond, fund, manager)     3
# 16           (asset, back, commercial)     3
# 17        (senior, portfolio, manager)     3
# 18         (commercial, paper, market)     3
# 19             (outlook, 2008, summit)     3
#
#                               Trigrams      PMI
# 0                (cnnmoney, com,     )  23.3531
# 1   (collateralized, debt, obligation)  21.3822
# 2         (chief, investment, officer)  18.8884
# 3                (sub, prime, lending)  17.0505
# 4               (sub, prime, mortgage)  15.8541
# 5           (mortgage, back, security)   15.542
# 6         (adjustable, rate, mortgage)   14.597
# 7                (money, market, fund)  13.3593
# 8         (subprime, mortgage, crisis)  12.3638
# 9                                 None     None
# 10                                None     None
# 11                                None     None
# 12                                None     None
# 13                                None     None
# 14                                None     None
# 15                                None     None
# 16                                None     None
# 17                                None     None
# 18                                None     None
# 19                                None     None
